# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('africa_recession.csv')

# %%
df.isnull().sum()
# Out:
# pop                       0
# emp                       0
# emp_to_pop_ratio          0
# hc                        0
# ccon                      0
# cda                       0
# cn                        0
# ck                        0
# ctfp                      0
# cwtfp                     0
# rconna                    0
# rdana                     0
# rnna                      0
# rkna                      0
# rtfpna                    0
# rwtfpna                   0
# labsh                     0
# irr                       0
# delta                     0
# xr                        0
# pl_con                    0
# pl_da                     0
# pl_gdpo                   0
# csh_c                     0
# csh_i                     0
# csh_g                     0
# csh_x                     0
# csh_m                     0
# csh_r                     0
# pl_c                      0
# pl_i                      0
# pl_g                      0
# pl_x                      0
# ...

# %%
df.head()
# Out:
#          pop        emp  emp_to_pop_ratio        hc           ccon  \
# 0  28.849621   6.914298          0.239667  1.547767   99010.171880
# 1  45.728313  13.623806          0.297929  2.086037  316862.656300
# 2  33.262043  13.323813          0.400571  1.498783   29762.876950
# 3   8.025703   3.869000          0.482076  1.356151    6488.692871
# 4   1.061468   0.243000          0.228928  1.676330    7620.187500
#
#              cda             cn        ck      ctfp     cwtfp  ...  \
# 0  131991.375000  426543.343800  0.009374  0.648979  0.626111  ...
# 1  374842.343800  804602.250000  0.019658  0.719390  0.657543  ...
# 2   36584.992190   67072.593750  0.001670  0.308652  0.292607  ...
# 3    7006.969727    5790.396973  0.000184  0.205865  0.234643  ...
# 4    8419.264648   16907.236330  0.000431  0.959765  0.993985  ...
#
#    agriculture    fish  total_change  excl_energy_change  energy_change  \
# 0       149.37  876.46      0.264843            0.012115       0.717188
# ...

# %%
# df1 = df.copy()
# df1.head()

# X = df1.drop('growthbucket', axis=1)
# y = df1['growthbucket']

# from sklearn.ensemble import RandomForestClassifier
# # Initializing the Random Forest classifier
# rf = RandomForestClassifier()
# rf.fit(X, y)
# importances = rf.feature_importances_

# feature_importances = pd.DataFrame({'Feature': X.columns, 'Importance': importances})
# feature_importances = feature_importances.sort_values('Importance', ascending=False)

# # Plotting the feature importances
# plt.figure(figsize=(10, 6))
# plt.barh(feature_importances['Feature'], feature_importances['Importance'])
# plt.xlabel('Importance')
# plt.ylabel('Feature')
# plt.title('Feature Importance')
# plt.show()

# # Printing the feature importances
# print(feature_importances)

# %%
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Create a synthetic dataset


# # Calculate the correlation matrix
# correlation_matrix = df.corr()

# # Display the correlation matrix
# print(correlation_matrix)

# # Visualize the correlation matrix as a heatmap
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
# plt.title('Correlation Matrix')
# plt.show()

# %%
df.columns
# Out:
# Index(['pop', 'emp', 'emp_to_pop_ratio', 'hc', 'ccon', 'cda', 'cn', 'ck',
#        'ctfp', 'cwtfp', 'rconna', 'rdana', 'rnna', 'rkna', 'rtfpna', 'rwtfpna',
#        'labsh', 'irr', 'delta', 'xr', 'pl_con', 'pl_da', 'pl_gdpo', 'csh_c',
#        'csh_i', 'csh_g', 'csh_x', 'csh_m', 'csh_r', 'pl_c', 'pl_i', 'pl_g',
#        'pl_x', 'pl_m', 'pl_n', 'total', 'excl_energy', 'energy',
#        'metals_minerals', 'forestry', 'agriculture', 'fish', 'total_change',
#        'excl_energy_change', 'energy_change', 'metals_minerals_change',
#        'forestry_change', 'agriculture_change', 'fish_change', 'growthbucket'],
#       dtype='object')

# %%
df_new = df[['ctfp','cwtfp','rwtfpna','csh_g','csh_r','pl_i', 'pl_g', 'pl_x', 'total','excl_energy', 'metals_minerals', 'agriculture', 'total_change', 'fish_change','growthbucket']]
df_new.head()
# Out:
#        ctfp     cwtfp   rwtfpna     csh_g     csh_r      pl_i      pl_g  \
# 0  0.648979  0.626111  1.008857  0.134649  0.056574  0.314139  0.388684
# 1  0.719390  0.657543  0.865942  0.133380  0.044295  0.385008  0.474147
# 2  0.308652  0.292607  0.816634  0.129643  0.065842  0.355546  0.304422
# 3  0.205865  0.234643  0.730731  0.229176 -0.192408  0.445609  0.238837
# 4  0.959765  0.993985  0.752696  0.130042 -0.020558  0.512144  0.247313
#
#        pl_x   total  excl_energy  metals_minerals  agriculture  total_change  \
# 0  0.465633  327.86       223.05           268.89       149.37      0.264843
# 1  0.494095  327.86       223.05           268.89       149.37      0.264843
# 2  0.501278  327.86       223.05           268.89       149.37      0.264843
# 3  0.470837  327.86       223.05           268.89       149.37      0.264843
# 4  0.487032  327.86       223.05           268.89       149.37      0.264843
#
#    fish_change  growthbucket
# 0     0.007576             0
# ...

# %%
X = df_new.drop('growthbucket', axis=1)
y = df_new[['growthbucket']]

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler instance
scaler = StandardScaler()

# Assuming 'X' is your pandas DataFrame, you can standardize only columns 8 to 11
X.iloc[:, 8:12] = scaler.fit_transform(X.iloc[:, 8:12])

# %%
X
# Out:
#          ctfp     cwtfp   rwtfpna     csh_g     csh_r      pl_i      pl_g  \
# 0    0.648979  0.626111  1.008857  0.134649  0.056574  0.314139  0.388684
# 1    0.719390  0.657543  0.865942  0.133380  0.044295  0.385008  0.474147
# 2    0.308652  0.292607  0.816634  0.129643  0.065842  0.355546  0.304422
# 3    0.205865  0.234643  0.730731  0.229176 -0.192408  0.445609  0.238837
# 4    0.959765  0.993985  0.752696  0.130042 -0.020558  0.512144  0.247313
# ..        ...       ...       ...       ...       ...       ...       ...
# 481  0.234562  0.248461  1.055834  0.108564 -0.027240  0.438269  0.528944
# 482  0.337927  0.287038  1.297615  0.133401 -0.115332  0.857789  0.679089
# 483  0.259968  0.248847  0.870758  0.158785  0.045189  0.389373  0.325423
# 484  0.470906  0.491789  0.963280  0.142207  0.002894  0.455558  0.410111
# 485  0.175976  0.188004  1.071506  0.233794  0.003492  0.534119  0.266571
#
#          pl_x     total  excl_energy  metals_minerals  agriculture  \
# ...

# %%
y
# Out:
#      growthbucket
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 481             0
# 482             1
# 483             0
# 484             0
# 485             0
#
# [486 rows x 1 columns]

# %%
zeroCount = 0
oneCount = 0
for i in y.values:
    if(i==1):
        oneCount += 1
    else:
        zeroCount += 1

# %%
print(zeroCount)
print(oneCount)
# Out:
# 448
# 38

# %%
import pandas as pd
from imblearn import over_sampling
from imblearn.over_sampling import SMOTE

# Assuming you have your dataset with features 'X' and target variable 'y'

# Initialize the SMOTE object
smote = SMOTE(sampling_strategy='auto', random_state=42)  # You can adjust 'sampling_strategy' as needed

# Apply SMOTE to your dataset
X_resampled, y_resampled = smote.fit_resample(X, y)

# X_resampled and y_resampled now contain the balanced dataset

# %%
#Exloratory Data Analysis
import seaborn as sns
import matplotlib.pyplot as plt

# Create a synthetic dataset


# Calculate the correlation matrix
correlation_matrix = df_new.corr()

# Display the correlation matrix
print(correlation_matrix)

# Visualize the correlation matrix as a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()
# Out:
#                      ctfp     cwtfp   rwtfpna     csh_g     csh_r      pl_i  \
# ctfp             1.000000  0.952274  0.157800 -0.192425  0.149710 -0.012687
# cwtfp            0.952274  1.000000  0.232345 -0.123310  0.109825 -0.071210
# rwtfpna          0.157800  0.232345  1.000000  0.082786  0.133736  0.261004
# csh_g           -0.192425 -0.123310  0.082786  1.000000 -0.009237 -0.166558
# csh_r            0.149710  0.109825  0.133736 -0.009237  1.000000 -0.078504
# pl_i            -0.012687 -0.071210  0.261004 -0.166558 -0.078504  1.000000
# pl_g             0.210870  0.197238  0.212998 -0.320373 -0.189117  0.599457
# pl_x            -0.135329 -0.014136  0.309391  0.236096  0.086134  0.202907
# total           -0.024984  0.006832  0.224052  0.045358 -0.029767  0.342780
# excl_energy     -0.091822 -0.038663  0.318669  0.121358 -0.006650  0.374242
# metals_minerals -0.086192 -0.031503  0.311654  0.101074 -0.017990  0.374407
# ...

# %%
#Feature Importance Graph
df1 = df_new.copy()
df1.head()

X = df1.drop('growthbucket', axis=1)
y = df1['growthbucket']

from sklearn.ensemble import RandomForestClassifier
# Initializing the Random Forest classifier
rf = RandomForestClassifier()
rf.fit(X, y)
importances = rf.feature_importances_

feature_importances = pd.DataFrame({'Feature': X.columns, 'Importance': importances})
feature_importances = feature_importances.sort_values('Importance', ascending=False)

# Plotting the feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_importances['Feature'], feature_importances['Importance'])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
# Initializing the Random Forest classifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# /home/harsh/Test/DAA-Research-Paper-main/.venv/lib/python3.10/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
y_pred = rf.predict(X_test)

# %%
accuracy = rf.score(X_test, y_test)

# %%
accuracy
# Out:
# 0.9166666666666666

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.92        95
#            1       0.87      0.96      0.92        85
#
#     accuracy                           0.92       180
#    macro avg       0.92      0.92      0.92       180
# weighted avg       0.92      0.92      0.92       180

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[83, 12],
#        [ 3, 82]])

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
# Out:
# /home/harsh/Test/DAA-Research-Paper-main/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_pred = svc.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.69      0.80        95
#            1       0.74      0.95      0.83        85
#
#     accuracy                           0.82       180
#    macro avg       0.84      0.82      0.82       180
# weighted avg       0.85      0.82      0.81       180

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
# Out:
# /home/harsh/Test/DAA-Research-Paper-main/.venv/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:228: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=1)

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_pred = knn.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95        95
#            1       0.91      0.98      0.94        85
#
#     accuracy                           0.94       180
#    macro avg       0.94      0.95      0.94       180
# weighted avg       0.95      0.94      0.94       180

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, y_train)
# Out:
# /home/harsh/Test/DAA-Research-Paper-main/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_pred = nb.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.73      0.77        95
#            1       0.73      0.82      0.77        85
#
#     accuracy                           0.77       180
#    macro avg       0.78      0.77      0.77       180
# weighted avg       0.78      0.77      0.77       180

# %%
#More graphs to show the accuracy of the model
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import random

# Compute ROC curve and ROC area for each class
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')  # random predictions curve
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate or (1 - Specifity)')
plt.ylabel('True Positive Rate or (Sensitivity)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Graphing the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Plotting the confusion matrix
plt.figure(figsize=(10, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
# Making more graphs to prove the accuracy of the model
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

# Compute Precision-Recall and plot curve
precision, recall, _ = precision_recall_curve(y_test, y_pred)
average_precision = average_precision_score(y_test, y_pred)

# Plot Precision-Recall curve
plt.figure(figsize=(10, 6))
plt.plot(recall, precision, label='Precision-Recall curve (area = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('PrecisionE')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# %%
#More graphs to visualize the accuracy of the model
#Pi chart
import matplotlib.pyplot as plt

# Data to plot
labels = '0', '1'
sizes = [zeroCount, oneCount]
colors = ['gold', 'yellowgreen']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.figure(figsize=(10, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Pi Chart')
plt.axis('equal')
plt.show()

# %%
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.82      0.73      0.77        95\n           1       0.73      0.82      0.77        85\n\n    accuracy                           0.77       180\n   macro avg       0.78      0.77      0.77       180\nweighted avg       0.78      0.77      0.77       180\n'

# %%
#Bar plot to understand the classificaiton report of the model
import matplotlib.pyplot as plt

# Data to plot
n_groups = 2

# Extracting the precision, recall, and f1-score from the classification report
precision = [0.99,0.89]
recall = [0.89,0.99]
f1_score = [0.94,0.94]

# Creating the bar plot
fig, ax = plt.subplots(figsize=(10, 6))
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8

rects1 = plt.bar(index, precision, bar_width, alpha=opacity, color='b', label='Precision')
rects2 = plt.bar(index + bar_width, recall, bar_width, alpha=opacity, color='g', label='Recall')
rects3 = plt.bar(index + bar_width + bar_width, f1_score, bar_width, alpha=opacity, color='r', label='F1-Score')

plt.xlabel('Class')
plt.ylabel('Scores')
plt.title('Scores by Class')
plt.xticks(index + bar_width, ('0', '1'))
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Applying Deep Learning and comparision graphs for it and machine learning

import tensorflow as tf
# Out:
# 2023-09-21 13:30:17.214335: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-21 13:30:17.246934: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-21 13:30:17.247293: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-21 13:30:17.968542: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#INitialization
ann = tf.keras.models.Sequential()

# %%
#Adding input layer and hidden layers

ann.add(tf.keras.layers.Dense(units=6,activation='relu'))

ann.add(tf.keras.layers.Dense(units=6,activation="relu"))

ann.add(tf.keras.layers.Dense(units=6,activation="relu"))

# %%
ann.add(tf.keras.layers.Dense(units=1,activation="sigmoid"))

# %%
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
ann.fit(X_train, y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 1s 1ms/step - loss: 0.6987 - accuracy: 0.5070
# Epoch 2/100
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6852 - accuracy: 0.5503
# Epoch 3/100
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6808 - accuracy: 0.5810
# Epoch 4/100
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6782 - accuracy: 0.6215
# Epoch 5/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6761 - accuracy: 0.6411
# Epoch 6/100
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6744 - accuracy: 0.6034
# Epoch 7/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6720 - accuracy: 0.6187
# Epoch 8/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6698 - accuracy: 0.6299
# Epoch 9/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6676 - accuracy: 0.6173
# Epoch 10/100
# ...

# %%
#Confusion Matrix and Classification Report
y_pred = ann.predict(X_test)
y_pred = (y_pred > 0.5)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# 6/6 [==============================] - 0s 1ms/step
# [[71 24]
#  [ 1 84]]
# 0.8611111111111112

# %%
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.99      0.75      0.85        95\n           1       0.78      0.99      0.87        85\n\n    accuracy                           0.86       180\n   macro avg       0.88      0.87      0.86       180\nweighted avg       0.89      0.86      0.86       180\n'

# %%
zeroCount = 0
oneCount = 0
for i in y_test.values:
    if(i==1):
        oneCount += 1
    else:
        zeroCount += 1

# %%
#Graphs to show the accuracy of the model
#Pi chart

import matplotlib.pyplot as plt

# Data to plot
labels = '0', '1'
sizes = [zeroCount, oneCount]
colors = ['gold', 'yellowgreen']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.figure(figsize=(10, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Pi Chart')
plt.axis('equal')
plt.show()

# %%
#Bar plot to understand the classificaiton report of the model
import matplotlib.pyplot as plt

# Data to plot
n_groups = 2

# Extracting the precision, recall, and f1-score from the classification report
precision = [0.99,0.80]
recall = [0.75,0.99]
f1_score = [0.85,0.87]

# Creating the bar plot
fig, ax = plt.subplots(figsize=(10, 6))
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8

rects1 = plt.bar(index, precision, bar_width, alpha=opacity, color='b', label='Precision')

rects2 = plt.bar(index + bar_width, recall, bar_width, alpha=opacity, color='g', label='Recall')

rects3 = plt.bar(index + bar_width + bar_width, f1_score, bar_width, alpha=opacity, color='r', label='F1-Score')

plt.xlabel('Class')
plt.ylabel('Scores')
plt.title('Scores by Class')
plt.xticks(index + bar_width, ('0', '1'))
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Graph to compare the accuracy of the machine learning and deep learning model
import matplotlib.pyplot as plt

# Data to plot
n_groups = 2
accuracy2 = [0.98,0.80]
accuracy = [0.97,0.87]

# Creating the bar plot
fig, ax = plt.subplots(figsize=(10, 6))
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8

rects1 = plt.bar(index, accuracy, bar_width, alpha=opacity, color='b', label='Machine Learning')

rects2 = plt.bar(index + bar_width, accuracy2, bar_width, alpha=opacity, color='g', label='Deep Learning')

plt.xlabel('Class')
plt.ylabel('Accuracy')
plt.title('Accuracy by Class')
plt.xticks(index + bar_width, ('0', '1'))
plt.legend()
plt.tight_layout()
plt.show()
